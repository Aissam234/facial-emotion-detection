# %%
import numpy as np
import os
import csv
from PIL import Image
import matplotlib.pyplot as plt
from tqdm import tqdm

# TensorFlow imports
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Dropout, Flatten, Dense, BatchNormalization
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau, ModelCheckpoint

# %%
emotion_map = {
    0: 'angry',
    1: 'contempt',
    2: 'disgusted',
    3: 'fearful',
    4: 'happy',
    5: 'neutral',
    6: 'sad',
    7: 'surprised'
}
base_dir = 'data'
train_dir = os.path.join(base_dir, 'train')
val_dir = os.path.join(base_dir, 'test')
for subset in [train_dir, val_dir]:
    for emotion in emotion_map.values():
        os.makedirs(os.path.join(subset, emotion), exist_ok=True)

# %%
print("Preparing image files...")
with open('affectnet_yolo_formatted_96x96.csv', 'r') as f:
    reader = csv.DictReader(f)
    for idx, row in enumerate(tqdm(reader)):
        pixels = np.fromstring(row['pixels'], sep=' ', dtype=np.uint8).reshape(96, 96)
        emotion = emotion_map[int(row['emotion'])]
        subset = 'train' if row['Usage'] == 'Training' else 'test'
        img_path = os.path.join(base_dir, subset, emotion, f'{idx}.png')
        Image.fromarray(pixels).save(img_path)
# Out:
# Preparing image files...
# 17465it [00:44, 388.60it/s]

# %%
batch_size = 64
num_epoch = 150

# %%
train_datagen = ImageDataGenerator(
    rescale=1./255,
    rotation_range=15,
    width_shift_range=0.15,
    height_shift_range=0.15,
    shear_range=0.15,
    zoom_range=0.15,
    horizontal_flip=True,
    fill_mode='nearest'
)

# Only rescaling for validation
validation_datagen = ImageDataGenerator(rescale=1./255)

train_gen = train_datagen.flow_from_directory(
    train_dir,
    target_size=(96, 96),
    batch_size=batch_size,
    color_mode='grayscale',
    class_mode='categorical'
)

val_gen = validation_datagen.flow_from_directory(
    val_dir,
    target_size=(96, 96),
    batch_size=batch_size,
    color_mode='grayscale',
    class_mode='categorical',
    shuffle=False
)
# Out:
# Found 12167 images belonging to 8 classes.
# Found 5298 images belonging to 8 classes.

# %%
model = Sequential([
    # First convolutional block
    Conv2D(32, (3, 3), padding='same', activation='relu', input_shape=(96, 96, 1)),
    BatchNormalization(),
    Conv2D(32, (3, 3), padding='same', activation='relu'),
    BatchNormalization(),
    MaxPooling2D(pool_size=(2, 2)),
    Dropout(0.2),
    
    # Second convolutional block
    Conv2D(64, (3, 3), padding='same', activation='relu'),
    BatchNormalization(),
    Conv2D(64, (3, 3), padding='same', activation='relu'),
    BatchNormalization(),
    MaxPooling2D(pool_size=(2, 2)),
    Dropout(0.3),
    
    # Third convolutional block
    Conv2D(128, (3, 3), padding='same', activation='relu'),
    BatchNormalization(),
    Conv2D(128, (3, 3), padding='same', activation='relu'),
    BatchNormalization(),
    MaxPooling2D(pool_size=(2, 2)),
    Dropout(0.4),
    
    # Flatten and dense layers
    Flatten(),
    Dense(512, activation='relu'),
    BatchNormalization(),
    Dropout(0.5),
    Dense(8, activation='softmax')
])
# Out:
# C:\Users\pc\AppData\Local\Programs\Python\Python39\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model.compile(
    loss='categorical_crossentropy',
    optimizer=Adam(learning_rate=0.0001),
    metrics=['accuracy']
)

model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                      │ (None, 96, 96, 32)          │             320 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization                  │ (None, 96, 96, 32)          │             128 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_1 (Conv2D)                    │ (None, 96, 96, 32)          │           9,248 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_1                │ (None, 96, 96, 32)          │             128 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d (MaxPooling2D)         │ (None, 48, 48, 32)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 48, 48, 32)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_2 (Conv2D)                    │ (None, 48, 48, 64)          │          18,496 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_2                │ (None, 48, 48, 64)          │             256 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_3 (Conv2D)                    │ (None, 48, 48, 64)          │          36,928 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_3                │ (None, 48, 48, 64)          │             256 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_1 (MaxPooling2D)       │ (None, 24, 24, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_1 (Dropout)                  │ (None, 24, 24, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_4 (Conv2D)                    │ (None, 24, 24, 128)         │          73,856 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_4                │ (None, 24, 24, 128)         │             512 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_5 (Conv2D)                    │ (None, 24, 24, 128)         │         147,584 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_5                │ (None, 24, 24, 128)         │             512 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_2 (MaxPooling2D)       │ (None, 12, 12, 128)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_2 (Dropout)                  │ (None, 12, 12, 128)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten (Flatten)                    │ (None, 18432)               │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 512)                 │       9,437,696 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_6                │ (None, 512)                 │           2,048 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_3 (Dropout)                  │ (None, 512)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 8)                   │           4,104 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 9,732,072 (37.12 MB)
#  Trainable params: 9,730,152 (37.12 MB)
#  Non-trainable params: 1,920 (7.50 KB)

# %%
early_stopping = EarlyStopping(
    monitor='val_loss',
    patience=10,
    verbose=1,
    restore_best_weights=True
)

reduce_lr = ReduceLROnPlateau(
    monitor='val_loss',
    factor=0.2,
    patience=5,
    min_lr=1e-6,
    verbose=1
)

checkpoint = ModelCheckpoint(
    'best_emotion_model_v4.keras',
    monitor='val_accuracy',
    mode='max',
    save_best_only=True,
    verbose=1
)

print("Starting training...")
history_1 = model.fit(
    train_gen,
    epochs=num_epoch,
    validation_data=val_gen,
    callbacks=[early_stopping, reduce_lr, checkpoint]
)

model.save('emotion_model_v4.h5')
# Out:
# Starting training...
# C:\Users\pc\AppData\Local\Programs\Python\Python39\lib\site-packages\keras\src\trainers\data_adapters\py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/50
# 619/619 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.1688 - loss: 2.8939
# C:\Users\pc\AppData\Local\Programs\Python\Python39\lib\site-packages\keras\src\trainers\data_adapters\py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1: val_accuracy improved from -inf to 0.16359, saving model to best_emotion_model_v4.keras
# 619/619 ━━━━━━━━━━━━━━━━━━━━ 868s 1s/step - accuracy: 0.1688 - loss: 2.8935 - val_accuracy: 0.1636 - val_loss: 3.1513 - learning_rate: 1.0000e-04
# Epoch 2/50
# 619/619 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.1994 - loss: 2.3533
# Epoch 2: val_accuracy improved from 0.16359 to 0.22411, saving model to best_emotion_model_v4.keras
# 619/619 ━━━━━━━━━━━━━━━━━━━━ 872s 1s/step - accuracy: 0.1994 - loss: 2.3532 - val_accuracy: 0.2241 - val_loss: 2.3477 - learning_rate: 1.0000e-04
# Epoch 3/50
# 619/619 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.2343 - loss: 2.1895
# Epoch 3: val_accuracy improved from 0.22411 to 0.29416, saving model to best_emotion_model_v4.keras
# 619/619 ━━━━━━━━━━━━━━━━━━━━ 843s 1s/step - accuracy: 0.2343 - loss: 2.1894 - val_accuracy: 0.2942 - val_loss: 1.9313 - learning_rate: 1.0000e-04
# Epoch 4/50
# 619/619 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.2651 - loss: 2.0777
# Epoch 4: val_accuracy did not improve from 0.29416
# 619/619 ━━━━━━━━━━━━━━━━━━━━ 844s 1s/step - accuracy: 0.2651 - loss: 2.0777 - val_accuracy: 0.2843 - val_loss: 1.9839 - learning_rate: 1.0000e-04
# Epoch 5/50
# 619/619 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.2890 - loss: 1.9742
# Epoch 5: val_accuracy improved from 0.29416 to 0.30226, saving model to best_emotion_model_v4.keras
# 619/619 ━━━━━━━━━━━━━━━━━━━━ 833s 1s/step - accuracy: 0.2890 - loss: 1.9741 - val_accuracy: 0.3023 - val_loss: 1.9050 - learning_rate: 1.0000e-04
# Epoch 6/50
# 619/619 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.3116 - loss: 1.9044
# Epoch 6: val_accuracy improved from 0.30226 to 0.39211, saving model to best_emotion_model_v4.keras
# 619/619 ━━━━━━━━━━━━━━━━━━━━ 832s 1s/step - accuracy: 0.3116 - loss: 1.9043 - val_accuracy: 0.3921 - val_loss: 1.6329 - learning_rate: 1.0000e-04
# Epoch 7/50
# 619/619 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.3307 - loss: 1.8107
# Epoch 7: val_accuracy did not improve from 0.39211
# 619/619 ━━━━━━━━━━━━━━━━━━━━ 837s 1s/step - accuracy: 0.3307 - loss: 1.8107 - val_accuracy: 0.3726 - val_loss: 1.6893 - learning_rate: 1.0000e-04
# Epoch 8/50
# 619/619 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.3624 - loss: 1.7174
# Epoch 8: val_accuracy did not improve from 0.39211
# 619/619 ━━━━━━━━━━━━━━━━━━━━ 835s 1s/step - accuracy: 0.3624 - loss: 1.7174 - val_accuracy: 0.3697 - val_loss: 1.7267 - learning_rate: 1.0000e-04
# Epoch 9/50
# 619/619 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.3831 - loss: 1.6614
# Epoch 9: val_accuracy improved from 0.39211 to 0.43083, saving model to best_emotion_model_v4.keras
# 619/619 ━━━━━━━━━━━━━━━━━━━━ 840s 1s/step - accuracy: 0.3831 - loss: 1.6613 - val_accuracy: 0.4308 - val_loss: 1.5517 - learning_rate: 1.0000e-04
# Epoch 10/50
# 619/619 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.3987 - loss: 1.6074
# Epoch 10: val_accuracy did not improve from 0.43083
# 619/619 ━━━━━━━━━━━━━━━━━━━━ 839s 1s/step - accuracy: 0.3987 - loss: 1.6074 - val_accuracy: 0.4275 - val_loss: 1.6162 - learning_rate: 1.0000e-04
# Epoch 11/50
# 619/619 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.4170 - loss: 1.5466
# Epoch 11: val_accuracy improved from 0.43083 to 0.46930, saving model to best_emotion_model_v4.keras
# 619/619 ━━━━━━━━━━━━━━━━━━━━ 843s 1s/step - accuracy: 0.4170 - loss: 1.5466 - val_accuracy: 0.4693 - val_loss: 1.4146 - learning_rate: 1.0000e-04
# Epoch 12/50
# 619/619 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.4265 - loss: 1.5110
# Epoch 12: val_accuracy improved from 0.46930 to 0.48774, saving model to best_emotion_model_v4.keras
# 619/619 ━━━━━━━━━━━━━━━━━━━━ 842s 1s/step - accuracy: 0.4265 - loss: 1.5110 - val_accuracy: 0.4877 - val_loss: 1.3654 - learning_rate: 1.0000e-04
# Epoch 13/50
# 619/619 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.4442 - loss: 1.4754
# Epoch 13: val_accuracy did not improve from 0.48774
# 619/619 ━━━━━━━━━━━━━━━━━━━━ 837s 1s/step - accuracy: 0.4442 - loss: 1.4754 - val_accuracy: 0.4837 - val_loss: 1.3785 - learning_rate: 1.0000e-04
# Epoch 14/50
# 619/619 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.4574 - loss: 1.4398
# Epoch 14: val_accuracy improved from 0.48774 to 0.49679, saving model to best_emotion_model_v4.keras
# 619/619 ━━━━━━━━━━━━━━━━━━━━ 839s 1s/step - accuracy: 0.4574 - loss: 1.4397 - val_accuracy: 0.4968 - val_loss: 1.3450 - learning_rate: 1.0000e-04
# Epoch 15/50
# 619/619 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.4691 - loss: 1.4172
# Epoch 15: val_accuracy improved from 0.49679 to 0.51082, saving model to best_emotion_model_v4.keras
# 619/619 ━━━━━━━━━━━━━━━━━━━━ 837s 1s/step - accuracy: 0.4691 - loss: 1.4172 - val_accuracy: 0.5108 - val_loss: 1.3071 - learning_rate: 1.0000e-04
# Epoch 16/50
# 619/619 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.4766 - loss: 1.3950
# Epoch 16: val_accuracy improved from 0.51082 to 0.51226, saving model to best_emotion_model_v4.keras
# 619/619 ━━━━━━━━━━━━━━━━━━━━ 837s 1s/step - accuracy: 0.4766 - loss: 1.3950 - val_accuracy: 0.5123 - val_loss: 1.3106 - learning_rate: 1.0000e-04
# Epoch 17/50
# 619/619 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.4830 - loss: 1.3772
# Epoch 17: val_accuracy did not improve from 0.51226
# 619/619 ━━━━━━━━━━━━━━━━━━━━ 834s 1s/step - accuracy: 0.4830 - loss: 1.3772 - val_accuracy: 0.5032 - val_loss: 1.3303 - learning_rate: 1.0000e-04
# Epoch 18/50
# 619/619 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.4938 - loss: 1.3538
# Epoch 18: val_accuracy improved from 0.51226 to 0.53807, saving model to best_emotion_model_v4.keras
# 619/619 ━━━━━━━━━━━━━━━━━━━━ 837s 1s/step - accuracy: 0.4938 - loss: 1.3538 - val_accuracy: 0.5381 - val_loss: 1.2454 - learning_rate: 1.0000e-04
# Epoch 19/50
# 619/619 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.5029 - loss: 1.3256
# Epoch 19: val_accuracy did not improve from 0.53807
# 619/619 ━━━━━━━━━━━━━━━━━━━━ 842s 1s/step - accuracy: 0.5029 - loss: 1.3256 - val_accuracy: 0.5323 - val_loss: 1.2819 - learning_rate: 1.0000e-04
# Epoch 20/50
# 619/619 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.5068 - loss: 1.3175
# Epoch 20: val_accuracy improved from 0.53807 to 0.54008, saving model to best_emotion_model_v4.keras
# 619/619 ━━━━━━━━━━━━━━━━━━━━ 839s 1s/step - accuracy: 0.5068 - loss: 1.3175 - val_accuracy: 0.5401 - val_loss: 1.3160 - learning_rate: 1.0000e-04
# Epoch 21/50
# 619/619 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.5122 - loss: 1.3047
# Epoch 21: val_accuracy improved from 0.54008 to 0.55891, saving model to best_emotion_model_v4.keras
# 619/619 ━━━━━━━━━━━━━━━━━━━━ 836s 1s/step - accuracy: 0.5122 - loss: 1.3047 - val_accuracy: 0.5589 - val_loss: 1.1890 - learning_rate: 1.0000e-04
# Epoch 22/50
# 619/619 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.5200 - loss: 1.2796
# Epoch 22: val_accuracy did not improve from 0.55891
# 619/619 ━━━━━━━━━━━━━━━━━━━━ 837s 1s/step - accuracy: 0.5200 - loss: 1.2796 - val_accuracy: 0.5121 - val_loss: 1.3795 - learning_rate: 1.0000e-04
# Epoch 23/50
# 619/619 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.5220 - loss: 1.2689
# Epoch 23: val_accuracy did not improve from 0.55891
# 619/619 ━━━━━━━━━━━━━━━━━━━━ 836s 1s/step - accuracy: 0.5220 - loss: 1.2689 - val_accuracy: 0.5573 - val_loss: 1.2018 - learning_rate: 1.0000e-04
# Epoch 24/50
# 619/619 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.5245 - loss: 1.2642
# Epoch 24: val_accuracy improved from 0.55891 to 0.56340, saving model to best_emotion_model_v4.keras
# 619/619 ━━━━━━━━━━━━━━━━━━━━ 836s 1s/step - accuracy: 0.5245 - loss: 1.2642 - val_accuracy: 0.5634 - val_loss: 1.1791 - learning_rate: 1.0000e-04
# Epoch 25/50
# 619/619 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.5416 - loss: 1.2391
# Epoch 25: val_accuracy did not improve from 0.56340
# 619/619 ━━━━━━━━━━━━━━━━━━━━ 841s 1s/step - accuracy: 0.5416 - loss: 1.2391 - val_accuracy: 0.5624 - val_loss: 1.1849 - learning_rate: 1.0000e-04
# Epoch 26/50
# 619/619 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.5444 - loss: 1.2199
# Epoch 26: val_accuracy improved from 0.56340 to 0.58448, saving model to best_emotion_model_v4.keras
# 619/619 ━━━━━━━━━━━━━━━━━━━━ 839s 1s/step - accuracy: 0.5444 - loss: 1.2199 - val_accuracy: 0.5845 - val_loss: 1.1242 - learning_rate: 1.0000e-04
# Epoch 27/50
# 619/619 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.5482 - loss: 1.2122
# Epoch 27: val_accuracy did not improve from 0.58448
# 619/619 ━━━━━━━━━━━━━━━━━━━━ 837s 1s/step - accuracy: 0.5481 - loss: 1.2122 - val_accuracy: 0.5738 - val_loss: 1.1502 - learning_rate: 1.0000e-04
# Epoch 28/50
# 619/619 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.5500 - loss: 1.2049
# Epoch 28: val_accuracy did not improve from 0.58448
# 619/619 ━━━━━━━━━━━━━━━━━━━━ 838s 1s/step - accuracy: 0.5500 - loss: 1.2049 - val_accuracy: 0.5582 - val_loss: 1.1916 - learning_rate: 1.0000e-04
# Epoch 29/50
# 619/619 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.5546 - loss: 1.1993
# Epoch 29: val_accuracy did not improve from 0.58448
# 619/619 ━━━━━━━━━━━━━━━━━━━━ 838s 1s/step - accuracy: 0.5546 - loss: 1.1993 - val_accuracy: 0.5668 - val_loss: 1.1710 - learning_rate: 1.0000e-04
# Epoch 30/50
# 619/619 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.5598 - loss: 1.1777
# Epoch 30: val_accuracy did not improve from 0.58448
# 619/619 ━━━━━━━━━━━━━━━━━━━━ 836s 1s/step - accuracy: 0.5598 - loss: 1.1777 - val_accuracy: 0.5818 - val_loss: 1.1523 - learning_rate: 1.0000e-04
# Epoch 31/50
# 619/619 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.5534 - loss: 1.1905
# Epoch 31: val_accuracy improved from 0.58448 to 0.60324, saving model to best_emotion_model_v4.keras
# 619/619 ━━━━━━━━━━━━━━━━━━━━ 837s 1s/step - accuracy: 0.5534 - loss: 1.1905 - val_accuracy: 0.6032 - val_loss: 1.0730 - learning_rate: 1.0000e-04
# Epoch 32/50
# 619/619 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.5624 - loss: 1.1792
# Epoch 32: val_accuracy did not improve from 0.60324
# 619/619 ━━━━━━━━━━━━━━━━━━━━ 839s 1s/step - accuracy: 0.5624 - loss: 1.1792 - val_accuracy: 0.5920 - val_loss: 1.1080 - learning_rate: 1.0000e-04
# Epoch 33/50
# 619/619 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.5615 - loss: 1.1785
# Epoch 33: val_accuracy did not improve from 0.60324
# 619/619 ━━━━━━━━━━━━━━━━━━━━ 838s 1s/step - accuracy: 0.5615 - loss: 1.1784 - val_accuracy: 0.5745 - val_loss: 1.1476 - learning_rate: 1.0000e-04
# Epoch 34/50
# 619/619 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.5687 - loss: 1.1587
# Epoch 34: val_accuracy improved from 0.60324 to 0.61069, saving model to best_emotion_model_v4.keras
# 619/619 ━━━━━━━━━━━━━━━━━━━━ 839s 1s/step - accuracy: 0.5688 - loss: 1.1587 - val_accuracy: 0.6107 - val_loss: 1.0526 - learning_rate: 1.0000e-04
# Epoch 35/50
# 619/619 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.5695 - loss: 1.1557
# Epoch 35: val_accuracy did not improve from 0.61069
# 619/619 ━━━━━━━━━━━━━━━━━━━━ 849s 1s/step - accuracy: 0.5695 - loss: 1.1557 - val_accuracy: 0.6037 - val_loss: 1.0620 - learning_rate: 1.0000e-04
# Epoch 36/50
# 619/619 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.5711 - loss: 1.1436
# Epoch 36: val_accuracy did not improve from 0.61069
# 619/619 ━━━━━━━━━━━━━━━━━━━━ 840s 1s/step - accuracy: 0.5711 - loss: 1.1436 - val_accuracy: 0.5804 - val_loss: 1.1437 - learning_rate: 1.0000e-04
# Epoch 37/50
# 619/619 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.5753 - loss: 1.1339
# Epoch 37: val_accuracy did not improve from 0.61069
# 619/619 ━━━━━━━━━━━━━━━━━━━━ 838s 1s/step - accuracy: 0.5753 - loss: 1.1339 - val_accuracy: 0.5979 - val_loss: 1.0766 - learning_rate: 1.0000e-04
# Epoch 38/50
# 619/619 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.5778 - loss: 1.1396
# Epoch 38: val_accuracy did not improve from 0.61069
# 619/619 ━━━━━━━━━━━━━━━━━━━━ 835s 1s/step - accuracy: 0.5778 - loss: 1.1396 - val_accuracy: 0.5810 - val_loss: 1.1289 - learning_rate: 1.0000e-04
# Epoch 39/50
# 619/619 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.5771 - loss: 1.1317
# Epoch 39: ReduceLROnPlateau reducing learning rate to 1.9999999494757503e-05.
#
# Epoch 39: val_accuracy did not improve from 0.61069
# 619/619 ━━━━━━━━━━━━━━━━━━━━ 836s 1s/step - accuracy: 0.5771 - loss: 1.1317 - val_accuracy: 0.6001 - val_loss: 1.0792 - learning_rate: 1.0000e-04
# Epoch 40/50
# 619/619 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.5875 - loss: 1.1063
# Epoch 40: val_accuracy improved from 0.61069 to 0.61775, saving model to best_emotion_model_v4.keras
# 619/619 ━━━━━━━━━━━━━━━━━━━━ 836s 1s/step - accuracy: 0.5875 - loss: 1.1063 - val_accuracy: 0.6177 - val_loss: 1.0252 - learning_rate: 2.0000e-05
# Epoch 41/50
# 619/619 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.5851 - loss: 1.1040
# Epoch 41: val_accuracy improved from 0.61775 to 0.61839, saving model to best_emotion_model_v4.keras
# 619/619 ━━━━━━━━━━━━━━━━━━━━ 837s 1s/step - accuracy: 0.5851 - loss: 1.1040 - val_accuracy: 0.6184 - val_loss: 1.0286 - learning_rate: 2.0000e-05
# Epoch 42/50
# 619/619 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.5905 - loss: 1.0977
# Epoch 42: val_accuracy did not improve from 0.61839
# 619/619 ━━━━━━━━━━━━━━━━━━━━ 837s 1s/step - accuracy: 0.5905 - loss: 1.0977 - val_accuracy: 0.6130 - val_loss: 1.0264 - learning_rate: 2.0000e-05
# Epoch 43/50
# 619/619 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.5885 - loss: 1.1025
# Epoch 43: val_accuracy improved from 0.61839 to 0.61895, saving model to best_emotion_model_v4.keras
# 619/619 ━━━━━━━━━━━━━━━━━━━━ 837s 1s/step - accuracy: 0.5885 - loss: 1.1025 - val_accuracy: 0.6189 - val_loss: 1.0140 - learning_rate: 2.0000e-05
# Epoch 44/50
# 619/619 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.5915 - loss: 1.0915
# Epoch 44: val_accuracy did not improve from 0.61895
# 619/619 ━━━━━━━━━━━━━━━━━━━━ 838s 1s/step - accuracy: 0.5915 - loss: 1.0915 - val_accuracy: 0.6161 - val_loss: 1.0301 - learning_rate: 2.0000e-05
# Epoch 45/50
# 619/619 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.5945 - loss: 1.0827
# Epoch 45: val_accuracy did not improve from 0.61895
# 619/619 ━━━━━━━━━━━━━━━━━━━━ 840s 1s/step - accuracy: 0.5945 - loss: 1.0828 - val_accuracy: 0.6169 - val_loss: 1.0214 - learning_rate: 2.0000e-05
# Epoch 46/50
# 619/619 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.5927 - loss: 1.0858
# Epoch 46: val_accuracy did not improve from 0.61895
# 619/619 ━━━━━━━━━━━━━━━━━━━━ 841s 1s/step - accuracy: 0.5927 - loss: 1.0858 - val_accuracy: 0.6172 - val_loss: 1.0228 - learning_rate: 2.0000e-05
# Epoch 47/50
# 619/619 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.5918 - loss: 1.0946
# Epoch 47: val_accuracy improved from 0.61895 to 0.61991, saving model to best_emotion_model_v4.keras
# 619/619 ━━━━━━━━━━━━━━━━━━━━ 841s 1s/step - accuracy: 0.5918 - loss: 1.0946 - val_accuracy: 0.6199 - val_loss: 1.0180 - learning_rate: 2.0000e-05
# Epoch 48/50
# 619/619 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.5981 - loss: 1.0736
# Epoch 48: ReduceLROnPlateau reducing learning rate to 3.999999898951501e-06.
#
# Epoch 48: val_accuracy did not improve from 0.61991
# 619/619 ━━━━━━━━━━━━━━━━━━━━ 840s 1s/step - accuracy: 0.5981 - loss: 1.0737 - val_accuracy: 0.6152 - val_loss: 1.0301 - learning_rate: 2.0000e-05
# Epoch 49/50
# 619/619 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.5980 - loss: 1.0803
# Epoch 49: val_accuracy improved from 0.61991 to 0.62320, saving model to best_emotion_model_v4.keras
# 619/619 ━━━━━━━━━━━━━━━━━━━━ 841s 1s/step - accuracy: 0.5980 - loss: 1.0803 - val_accuracy: 0.6232 - val_loss: 1.0055 - learning_rate: 4.0000e-06
# Epoch 50/50
# 619/619 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.6011 - loss: 1.0774
# Epoch 50: val_accuracy did not improve from 0.62320
# 619/619 ━━━━━━━━━━━━━━━━━━━━ 842s 1s/step - accuracy: 0.6011 - loss: 1.0774 - val_accuracy: 0.6227 - val_loss: 1.0057 - learning_rate: 4.0000e-06
# Restoring model weights from the end of the best epoch: 49.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
from tensorflow.keras.models import load_model

model = load_model('best_emotion_model_v5+++.keras')

model.compile(
    loss='categorical_crossentropy',
    optimizer=Adam(learning_rate=4.0000e-06),
    metrics=['accuracy']
)


early_stopping = EarlyStopping(
    monitor='val_loss',
    patience=10,
    verbose=1,
    restore_best_weights=True
)

reduce_lr = ReduceLROnPlateau(
    monitor='val_loss',
    factor=0.2,
    patience=5,
    min_lr=1e-6,
    verbose=1
)

checkpoint = ModelCheckpoint(
    'best_emotion_model_v6.keras',  
    monitor='val_accuracy',
    mode='max',
    save_best_only=True,
    verbose=1
)

print("Continuing training for 50 more epochs...")
history_2 = model.fit(
    train_gen,
    epochs=num_epoch,  
    validation_data=val_gen,
    callbacks=[early_stopping, reduce_lr, checkpoint],
    initial_epoch=100 
)

model.save('emotion_model_v5.keras')
# Out:
# Continuing training for 50 more epochs...
# Epoch 101/150
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.6691 - loss: 0.8916
# Epoch 101: val_accuracy improved from -inf to 0.69215, saving model to best_emotion_model_v6.keras
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 266s 1s/step - accuracy: 0.6691 - loss: 0.8915 - val_accuracy: 0.6921 - val_loss: 0.8153 - learning_rate: 4.0000e-06
# Epoch 102/150
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.6796 - loss: 0.8565
# Epoch 102: val_accuracy improved from 0.69215 to 0.69309, saving model to best_emotion_model_v6.keras
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 264s 1s/step - accuracy: 0.6796 - loss: 0.8565 - val_accuracy: 0.6931 - val_loss: 0.8142 - learning_rate: 4.0000e-06
# Epoch 103/150
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.6866 - loss: 0.8459
# Epoch 103: val_accuracy improved from 0.69309 to 0.69366, saving model to best_emotion_model_v6.keras
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 263s 1s/step - accuracy: 0.6866 - loss: 0.8460 - val_accuracy: 0.6937 - val_loss: 0.8136 - learning_rate: 4.0000e-06
# Epoch 104/150
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.6786 - loss: 0.8563
# Epoch 104: val_accuracy improved from 0.69366 to 0.69517, saving model to best_emotion_model_v6.keras
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 264s 1s/step - accuracy: 0.6786 - loss: 0.8562 - val_accuracy: 0.6952 - val_loss: 0.8124 - learning_rate: 4.0000e-06
# Epoch 105/150
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.6869 - loss: 0.8529
# Epoch 105: val_accuracy did not improve from 0.69517
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 263s 1s/step - accuracy: 0.6868 - loss: 0.8529 - val_accuracy: 0.6940 - val_loss: 0.8130 - learning_rate: 4.0000e-06
# Epoch 106/150
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.6833 - loss: 0.8531
# Epoch 106: val_accuracy did not improve from 0.69517
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 264s 1s/step - accuracy: 0.6833 - loss: 0.8531 - val_accuracy: 0.6938 - val_loss: 0.8099 - learning_rate: 4.0000e-06
# Epoch 107/150
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.6794 - loss: 0.8552
# Epoch 107: val_accuracy did not improve from 0.69517
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 272s 1s/step - accuracy: 0.6794 - loss: 0.8552 - val_accuracy: 0.6940 - val_loss: 0.8089 - learning_rate: 4.0000e-06
# Epoch 108/150
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.6792 - loss: 0.8509
# Epoch 108: val_accuracy did not improve from 0.69517
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 265s 1s/step - accuracy: 0.6792 - loss: 0.8509 - val_accuracy: 0.6952 - val_loss: 0.8084 - learning_rate: 4.0000e-06
# Epoch 109/150
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.6826 - loss: 0.8398
# Epoch 109: val_accuracy improved from 0.69517 to 0.69611, saving model to best_emotion_model_v6.keras
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 260s 1s/step - accuracy: 0.6826 - loss: 0.8398 - val_accuracy: 0.6961 - val_loss: 0.8080 - learning_rate: 4.0000e-06
# Epoch 110/150
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.6883 - loss: 0.8423
# Epoch 110: val_accuracy did not improve from 0.69611
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 261s 1s/step - accuracy: 0.6883 - loss: 0.8423 - val_accuracy: 0.6937 - val_loss: 0.8092 - learning_rate: 4.0000e-06
# Epoch 111/150
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.6707 - loss: 0.8675
# Epoch 111: val_accuracy did not improve from 0.69611
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 260s 1s/step - accuracy: 0.6708 - loss: 0.8675 - val_accuracy: 0.6959 - val_loss: 0.8074 - learning_rate: 4.0000e-06
# Epoch 112/150
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.6822 - loss: 0.8587
# Epoch 112: val_accuracy did not improve from 0.69611
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 260s 1s/step - accuracy: 0.6822 - loss: 0.8586 - val_accuracy: 0.6959 - val_loss: 0.8074 - learning_rate: 4.0000e-06
# Epoch 113/150
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.6768 - loss: 0.8554
# Epoch 113: val_accuracy improved from 0.69611 to 0.69724, saving model to best_emotion_model_v6.keras
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 261s 1s/step - accuracy: 0.6768 - loss: 0.8553 - val_accuracy: 0.6972 - val_loss: 0.8095 - learning_rate: 4.0000e-06
# Epoch 114/150
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.6882 - loss: 0.8308
# Epoch 114: val_accuracy did not improve from 0.69724
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 260s 1s/step - accuracy: 0.6882 - loss: 0.8308 - val_accuracy: 0.6965 - val_loss: 0.8074 - learning_rate: 4.0000e-06
# Epoch 115/150
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.6870 - loss: 0.8481
# Epoch 115: val_accuracy improved from 0.69724 to 0.69800, saving model to best_emotion_model_v6.keras
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 261s 1s/step - accuracy: 0.6870 - loss: 0.8481 - val_accuracy: 0.6980 - val_loss: 0.8081 - learning_rate: 4.0000e-06
# Epoch 116/150
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.6786 - loss: 0.8624
# Epoch 116: val_accuracy did not improve from 0.69800
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 260s 1s/step - accuracy: 0.6786 - loss: 0.8623 - val_accuracy: 0.6959 - val_loss: 0.8072 - learning_rate: 4.0000e-06
# Epoch 117/150
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.6787 - loss: 0.8615
# Epoch 117: val_accuracy did not improve from 0.69800
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 260s 1s/step - accuracy: 0.6786 - loss: 0.8615 - val_accuracy: 0.6967 - val_loss: 0.8069 - learning_rate: 4.0000e-06
# Epoch 118/150
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.6835 - loss: 0.8350
# Epoch 118: val_accuracy did not improve from 0.69800
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 260s 1s/step - accuracy: 0.6836 - loss: 0.8350 - val_accuracy: 0.6959 - val_loss: 0.8082 - learning_rate: 4.0000e-06
# Epoch 119/150
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.6813 - loss: 0.8628
# Epoch 119: val_accuracy did not improve from 0.69800
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 260s 1s/step - accuracy: 0.6813 - loss: 0.8628 - val_accuracy: 0.6961 - val_loss: 0.8081 - learning_rate: 4.0000e-06
# Epoch 120/150
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.6884 - loss: 0.8391
# Epoch 120: val_accuracy did not improve from 0.69800
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 260s 1s/step - accuracy: 0.6884 - loss: 0.8391 - val_accuracy: 0.6963 - val_loss: 0.8070 - learning_rate: 4.0000e-06
# Epoch 121/150
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.6765 - loss: 0.8577
# Epoch 121: val_accuracy did not improve from 0.69800
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 260s 1s/step - accuracy: 0.6766 - loss: 0.8577 - val_accuracy: 0.6959 - val_loss: 0.8065 - learning_rate: 4.0000e-06
# Epoch 122/150
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.6864 - loss: 0.8456
# Epoch 122: val_accuracy improved from 0.69800 to 0.69838, saving model to best_emotion_model_v6.keras
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 261s 1s/step - accuracy: 0.6864 - loss: 0.8455 - val_accuracy: 0.6984 - val_loss: 0.8073 - learning_rate: 4.0000e-06
# Epoch 123/150
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.6793 - loss: 0.8404
# Epoch 123: val_accuracy did not improve from 0.69838
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 262s 1s/step - accuracy: 0.6794 - loss: 0.8404 - val_accuracy: 0.6961 - val_loss: 0.8059 - learning_rate: 4.0000e-06
# Epoch 124/150
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.6915 - loss: 0.8353
# Epoch 124: val_accuracy improved from 0.69838 to 0.69857, saving model to best_emotion_model_v6.keras
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 288s 2s/step - accuracy: 0.6915 - loss: 0.8353 - val_accuracy: 0.6986 - val_loss: 0.8062 - learning_rate: 4.0000e-06
# Epoch 125/150
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.6763 - loss: 0.8646
# Epoch 125: val_accuracy did not improve from 0.69857
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 289s 2s/step - accuracy: 0.6763 - loss: 0.8646 - val_accuracy: 0.6957 - val_loss: 0.8062 - learning_rate: 4.0000e-06
# Epoch 126/150
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.6758 - loss: 0.8592
# Epoch 126: val_accuracy did not improve from 0.69857
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 293s 2s/step - accuracy: 0.6758 - loss: 0.8592 - val_accuracy: 0.6965 - val_loss: 0.8058 - learning_rate: 4.0000e-06
# Epoch 127/150
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.6755 - loss: 0.8474
# Epoch 127: val_accuracy did not improve from 0.69857
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 283s 1s/step - accuracy: 0.6756 - loss: 0.8474 - val_accuracy: 0.6955 - val_loss: 0.8048 - learning_rate: 4.0000e-06
# Epoch 128/150
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.6866 - loss: 0.8417
# Epoch 128: val_accuracy did not improve from 0.69857
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 285s 1s/step - accuracy: 0.6866 - loss: 0.8416 - val_accuracy: 0.6948 - val_loss: 0.8037 - learning_rate: 4.0000e-06
# Epoch 129/150
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.6823 - loss: 0.8265
# Epoch 129: val_accuracy did not improve from 0.69857
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 290s 2s/step - accuracy: 0.6823 - loss: 0.8265 - val_accuracy: 0.6971 - val_loss: 0.8049 - learning_rate: 4.0000e-06
# Epoch 130/150
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.6866 - loss: 0.8373
# Epoch 130: val_accuracy did not improve from 0.69857
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 295s 2s/step - accuracy: 0.6866 - loss: 0.8374 - val_accuracy: 0.6961 - val_loss: 0.8067 - learning_rate: 4.0000e-06
# Epoch 131/150
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.6827 - loss: 0.8458
# Epoch 131: val_accuracy did not improve from 0.69857
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 289s 2s/step - accuracy: 0.6827 - loss: 0.8458 - val_accuracy: 0.6957 - val_loss: 0.8049 - learning_rate: 4.0000e-06
# Epoch 132/150
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.6801 - loss: 0.8433
# Epoch 132: val_accuracy did not improve from 0.69857
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 291s 2s/step - accuracy: 0.6802 - loss: 0.8433 - val_accuracy: 0.6957 - val_loss: 0.8049 - learning_rate: 4.0000e-06
# Epoch 133/150
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.6897 - loss: 0.8348
# Epoch 133: ReduceLROnPlateau reducing learning rate to 1e-06.
#
# Epoch 133: val_accuracy did not improve from 0.69857
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 271s 1s/step - accuracy: 0.6897 - loss: 0.8348 - val_accuracy: 0.6952 - val_loss: 0.8060 - learning_rate: 4.0000e-06
# Epoch 134/150
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.6860 - loss: 0.8382
# Epoch 134: val_accuracy did not improve from 0.69857
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 263s 1s/step - accuracy: 0.6860 - loss: 0.8382 - val_accuracy: 0.6957 - val_loss: 0.8054 - learning_rate: 1.0000e-06
# Epoch 135/150
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.6845 - loss: 0.8425
# Epoch 135: val_accuracy did not improve from 0.69857
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 266s 1s/step - accuracy: 0.6845 - loss: 0.8425 - val_accuracy: 0.6957 - val_loss: 0.8047 - learning_rate: 1.0000e-06
# Epoch 136/150
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.6902 - loss: 0.8367
# Epoch 136: val_accuracy did not improve from 0.69857
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 274s 1s/step - accuracy: 0.6901 - loss: 0.8368 - val_accuracy: 0.6965 - val_loss: 0.8035 - learning_rate: 1.0000e-06
# Epoch 137/150
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.6906 - loss: 0.8264
# Epoch 137: val_accuracy did not improve from 0.69857
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 273s 1s/step - accuracy: 0.6906 - loss: 0.8264 - val_accuracy: 0.6963 - val_loss: 0.8047 - learning_rate: 1.0000e-06
# Epoch 138/150
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.6854 - loss: 0.8367
# Epoch 138: val_accuracy did not improve from 0.69857
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 265s 1s/step - accuracy: 0.6854 - loss: 0.8367 - val_accuracy: 0.6961 - val_loss: 0.8043 - learning_rate: 1.0000e-06
# Epoch 139/150
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.6782 - loss: 0.8571
# Epoch 139: val_accuracy did not improve from 0.69857
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 269s 1s/step - accuracy: 0.6782 - loss: 0.8571 - val_accuracy: 0.6961 - val_loss: 0.8046 - learning_rate: 1.0000e-06
# Epoch 140/150
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.6820 - loss: 0.8429
# Epoch 140: val_accuracy did not improve from 0.69857
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 277s 1s/step - accuracy: 0.6820 - loss: 0.8429 - val_accuracy: 0.6950 - val_loss: 0.8049 - learning_rate: 1.0000e-06
# Epoch 141/150
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.6837 - loss: 0.8362
# Epoch 141: val_accuracy did not improve from 0.69857
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 261s 1s/step - accuracy: 0.6837 - loss: 0.8362 - val_accuracy: 0.6948 - val_loss: 0.8051 - learning_rate: 1.0000e-06
# Epoch 142/150
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.6759 - loss: 0.8511
# Epoch 142: val_accuracy did not improve from 0.69857
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 260s 1s/step - accuracy: 0.6760 - loss: 0.8510 - val_accuracy: 0.6967 - val_loss: 0.8055 - learning_rate: 1.0000e-06
# Epoch 143/150
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.6852 - loss: 0.8258
# Epoch 143: val_accuracy did not improve from 0.69857
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 261s 1s/step - accuracy: 0.6852 - loss: 0.8258 - val_accuracy: 0.6961 - val_loss: 0.8048 - learning_rate: 1.0000e-06
# Epoch 144/150
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.6897 - loss: 0.8245
# Epoch 144: val_accuracy did not improve from 0.69857
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 260s 1s/step - accuracy: 0.6897 - loss: 0.8245 - val_accuracy: 0.6969 - val_loss: 0.8054 - learning_rate: 1.0000e-06
# Epoch 145/150
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.6772 - loss: 0.8610
# Epoch 145: val_accuracy did not improve from 0.69857
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 262s 1s/step - accuracy: 0.6772 - loss: 0.8609 - val_accuracy: 0.6967 - val_loss: 0.8043 - learning_rate: 1.0000e-06
# Epoch 146/150
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.6845 - loss: 0.8369
# Epoch 146: val_accuracy did not improve from 0.69857
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 262s 1s/step - accuracy: 0.6845 - loss: 0.8369 - val_accuracy: 0.6967 - val_loss: 0.8035 - learning_rate: 1.0000e-06
# Epoch 146: early stopping
# Restoring model weights from the end of the best epoch: 136.

# %%
from tensorflow.keras.models import load_model

model = load_model("emotion_model_v5.keras")
loss, accuracy = model.evaluate(val_gen)
print(f"\nModel Accuracy: {accuracy * 100:.2f}%")
# Out:
# C:\Users\pc\AppData\Local\Programs\Python\Python39\lib\site-packages\keras\src\trainers\data_adapters\py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 19s 219ms/step - accuracy: 0.7062 - loss: 0.7854
#
# Model Accuracy: 69.65%

# %%
plt.figure(figsize=(12,5))
plt.subplot(1,2,1)
plt.plot(history_1.history['accuracy'], label='Train Acc')
plt.plot(history_1.history['val_accuracy'], label='Val Acc')
plt.title('Accuracy')
plt.legend()

plt.subplot(1,2,2)
plt.plot(history_1.history['loss'], label='Train Loss')
plt.plot(history_1.history['val_loss'], label='Val Loss')
plt.title('Loss')
plt.legend()
plt.show()

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras.models import load_model

model = load_model("emotion_model_v5.keras")
emotion_labels = ['Angry', 'contempt', 'Disgusted', 'Fearful', 'Happy', 'neutral', 'sad', 'surprised']

img_path = "istockphoto-490608166-612x612.jpg"
img = cv2.imread(img_path)
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

face_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + "haarcascade_frontalface_default.xml")
faces = face_cascade.detectMultiScale(gray, scaleFactor=1.05, minNeighbors=5)

faces = list(faces)
faces, _ = cv2.groupRectangles(faces + faces, groupThreshold=1, eps=0.2)

print(f"{len(faces)} unique face(s) detected.")

for i, (x, y, w, h) in enumerate(faces):
    face = img[y:y+h, x:x+w]
    face_resized = cv2.resize(face, (96, 96))
    face_gray = cv2.cvtColor(face_resized, cv2.COLOR_BGR2GRAY)
    face_normalized = face_gray / 255.0
    face_input = face_normalized.reshape(1, 96, 96, 1)

    prediction = model.predict(face_input)[0]
    predicted_class = np.argmax(prediction)
    confidence = np.max(prediction)
    emotion = emotion_labels[predicted_class]

    img_copy = img.copy()
    cv2.rectangle(img_copy, (x, y), (x+w, y+h), (0, 255, 0), 2)

    plt.figure(figsize=(12, 5))

    plt.subplot(1, 2, 1)
    plt.imshow(cv2.cvtColor(img_copy, cv2.COLOR_BGR2RGB))
    plt.title(f"Face {i+1}: {emotion} ({confidence:.2f})")
    plt.axis('off')

    plt.subplot(1, 2, 2)
    plt.bar(emotion_labels, prediction, color='skyblue')
    plt.xticks(rotation=45)
    plt.ylabel('Probability')
    plt.title(f'Emotion Probabilities (Face {i+1})')

    plt.tight_layout()
    plt.show()
# Out:
# 6 unique face(s) detected.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 693ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step

# %%
# Start webcam
cap = cv2.VideoCapture(0)

print("Starting webcam... Press 'q' to quit.")
while True:
    ret, frame = cap.read()
    if not ret:
        break

    gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
    faces = face_cascade.detectMultiScale(gray, scaleFactor=1.3, minNeighbors=5)

    for (x, y, w, h) in faces:
        roi_gray = gray[y:y+h, x:x+w]
        roi_gray = cv2.resize(roi_gray, (96, 96))
        roi_gray = roi_gray / 255.0
        roi_gray = roi_gray.reshape(1, 96, 96, 1)

        prediction = model.predict(roi_gray, verbose=0)
        predicted_class = np.argmax(prediction)
        confidence = np.max(prediction)
        emotion = emotion_labels[predicted_class]

        cv2.rectangle(frame, (x, y), (x+w, y+h), (255, 0, 0), 2)
        cv2.putText(frame, f"{emotion} ({confidence:.2f})", (x, y - 10),
                    cv2.FONT_HERSHEY_SIMPLEX, 0.9, (255, 255, 255), 2)

    # Show frame
    cv2.imshow('Real-time Emotion Detection', frame)

    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

# Cleanup
cap.release()
cv2.destroyAllWindows()
# Out:
# Starting webcam... Press 'q' to quit.
